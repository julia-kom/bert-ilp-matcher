# %% [markdown]
# ##Visualization of the Matcher Results

# %%
# Imports
import seaborn as sns
import pandas as pd
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

# %%
# Birth Admission Label vs Behavior + Label
df_label = pd.read_csv("../../../eval-results/_server-results/batch-birth-BINARY-label/aggResults.eval",encoding = "ISO-8859-1", skipinitialspace=True)
df_behavior = pd.read_csv("../../../eval-results/_server-results/batch-birth-BINARY-behavior/aggResults.eval",encoding = "ISO-8859-1", skipinitialspace=True)




#combine the dataframes
df_label['matcher'] = "label"
df_behavior['matcher'] = "behavior"
df_combined = pd.concat([df_label,df_behavior])
df_combined.set_index(['Name',"matcher"])

df_combined

#df_combined['Name',"matcher","Precision", "Recall"]
fig, ax = plt.subplots()
# the size of A4 paper
g = sns.catplot(x="Name", y="PRECISION", hue="matcher", kind="bar", data=df_combined);
g.set_xticklabels(rotation=90)
g.set_axis(ax)
