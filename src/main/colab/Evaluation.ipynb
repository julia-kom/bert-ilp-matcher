# %% [markdown]
# ## Connect Google Drive

# %% [markdown]
# Connect your personal drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Copy pnml datasets into your personal drive and set the following paths

# %%
path = "/content/drive/MyDrive/ilp-matcher-bert/eval-results/"

# %%
path = "../../../eval-results/"

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### SAP Dataset

# %%
sap_bow = pd.read_csv(path + "sap_bow.eval")
sap_bert = pd.read_csv(path + "sap_bert.eval")
sap_bert_ft = pd.read_csv(path + "sap_bert_ft.eval")
sap_bow_ilp = pd.read_csv(path + "sap_bow_03.eval")
sap_bert_ilp = pd.read_csv(path + "sap_bert_03.eval")
sap_bert_ft_ilp = pd.read_csv(path + "sap_bert_ft_03.eval")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-d0cac01b6a42> in <module>()
# ----> 1 sap_bow = pd.read_csv(path + "sap_bow.eval")
#       2 sap_bert = pd.read_csv(path + "sap_bert.eval")
#       3 sap_bert_ft = pd.read_csv(path + "sap_bert_ft.eval")
#       4 sap_bow_ilp = pd.read_csv(path + "sap_bow_03.eval")
#       5 sap_bert_ilp = pd.read_csv(path + "sap_bert_03.eval")
#
# ...

# %%
sap_bow.head()
# Out:
#                     Name  TP  FP  ...    BP TIME  SIMILARITY  MIP GAP
# 0     Aggregated (MACRO)  56  34  ...   87390622    0.000000      0.0
# 1     Aggregated (MICRO)  56  34  ...   87390622    0.000000      0.0
# 2  sap9s.pnml-sap9t.pnml   3   4  ...  190322628    0.714813      0.0
# 3  sap8s.pnml-sap8t.pnml   1   2  ...   18547148    0.456804      0.0
# 4  sap6s.pnml-sap6t.pnml   8   0  ...   35572595    0.978125      0.0
#
# [5 rows x 13 columns]

# %%
sap_bert.head()
# Out:
#                     Name  TP  FP  ...    BP TIME  SIMILARITY  MIP GAP
# 0     Aggregated (MACRO)  59  31  ...  123204411    0.000000      0.0
# 1     Aggregated (MICRO)  59  31  ...  123204411    0.000000      0.0
# 2  sap9s.pnml-sap9t.pnml   3   4  ...  225376012    0.816880      0.0
# 3  sap8s.pnml-sap8t.pnml   1   2  ...   15323242    0.728417      0.0
# 4  sap6s.pnml-sap6t.pnml   8   0  ...   41382984    0.981279      0.0
#
# [5 rows x 13 columns]

# %%
sap_bert_ft.head()
# Out:
#                     Name  TP  FP  ...    BP TIME  SIMILARITY  MIP GAP
# 0     Aggregated (MACRO)  58  32  ...   87699982    0.000000      0.0
# 1     Aggregated (MICRO)  58  32  ...   87699982    0.000000      0.0
# 2  sap9s.pnml-sap9t.pnml   2   5  ...  150893607    0.955971      0.0
# 3  sap8s.pnml-sap8t.pnml   1   2  ...   13413362    0.951261      0.0
# 4  sap6s.pnml-sap6t.pnml   8   0  ...   19154668    0.994225      0.0
#
# [5 rows x 13 columns]

# %%
sap_bow_ilp.head()
# Out:
#                     Name  TP  FP  ...    BP TIME  SIMILARITY  MIP GAP
# 0     Aggregated (MACRO)  59  31  ...   87999724    0.000000      0.0
# 1     Aggregated (MICRO)  59  31  ...   87999724    0.000000      0.0
# 2  sap9s.pnml-sap9t.pnml   3   4  ...  183306823    0.726806      0.0
# 3  sap8s.pnml-sap8t.pnml   1   2  ...   24334089    0.596845      0.0
# 4  sap6s.pnml-sap6t.pnml   8   0  ...   26012141    0.984688      0.0
#
# [5 rows x 13 columns]

# %%
sap_bert_ilp.head()

# %%
sap_bert_ft_ilp.head()
# Out:
#                           Name  TP   FP  ...      BP TIME  SIMILARITY   MIP GAP
# 0           Aggregated (MACRO)  89  334  ...  29922719255    0.000000  0.000000
# 1           Aggregated (MICRO)  89  334  ...  29922719255    0.000000  0.000000
# 2  Cologne.pnml-FU_Berlin.pnml   4   12  ...   8299030376    0.863782  0.103464
# 3  Cologne.pnml-Wuerzburg.pnml   3   13  ...   4414209242    0.854182  0.116656
# 4  Cologne.pnml-Frankfurt.pnml   5   11  ...   4559302113    0.848708  0.147879
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Birth Dataset

# %%
birth_bow = pd.read_csv(path + "birth_bow.eval")
birth_bert = pd.read_csv(path + "birth_bert.eval")
birth_bert_ft = pd.read_csv(path + "birth_bert_ft.eval")
birth_bow_ilp = pd.read_csv(path + "birth_bow_03.eval")
birth_bert_ilp = pd.read_csv(path + "birth_bert_03.eval")
birth_bert_ft_ilp = pd.read_csv(path + "birth_bert_ft_03.eval")

# %%
birth_bow.head()

# %%
birth_bert.head()

# %%
birth_bert_ft.head()
# Out:
#                                                 Name   TP  ...  SIMILARITY  MIP GAP
# 0                                 Aggregated (MACRO)  177  ...    0.000000      0.0
# 1                                 Aggregated (MICRO)  177  ...    0.000000      0.0
# 2  birthCertificate_p34.pnml-birthCertificate_p24...    1  ...    0.779267      0.0
# 3  birthCertificate_p34.pnml-birthCertificate_p24...    1  ...    0.786113      0.0
# 4  birthCertificate_p34.pnml-birthCertificate_p25...    1  ...    0.775230      0.0
#
# [5 rows x 13 columns]

# %%
birth_bow_ilp.head()

# %%
birth_bert_ilp.head()

# %%
birth_bert_ft_ilp.head()
# Out:
#                                                 Name   TP  ...  SIMILARITY   MIP GAP
# 0                                 Aggregated (MACRO)  187  ...    0.000000  0.000000
# 1                                 Aggregated (MICRO)  187  ...    0.000000  0.000000
# 2  birthCertificate_p34.pnml-birthCertificate_p24...    1  ...    0.769407  0.085185
# 3  birthCertificate_p34.pnml-birthCertificate_p24...    1  ...    0.744198  0.127553
# 4  birthCertificate_p34.pnml-birthCertificate_p25...    2  ...    0.761390  0.091790
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Uni Dataset

# %%
uni_bow = pd.read_csv(path + "uni_bow.eval")
uni_bert = pd.read_csv(path + "uni_bert.eval")
uni_bert_ft = pd.read_csv(path + "uni_bert_ft.eval")
uni_bow_ilp = pd.read_csv(path + "uni_bow_03.eval")
uni_bert_ilp = pd.read_csv(path + "uni_bert_03.eval")
uni_bert_ft_ilp = pd.read_csv(path + "uni_bert_ft_03.eval")

# %%
uni_bow.head()

# %%
uni_bert.head()
# Out:
#                           Name  TP   FP  ...      BP TIME  SIMILARITY  MIP GAP
# 0           Aggregated (MACRO)  93  330  ...  30981281932    0.000000      0.0
# 1           Aggregated (MICRO)  93  330  ...  30981281932    0.000000      0.0
# 2  Cologne.pnml-FU_Berlin.pnml   4   12  ...   8133143146    0.733024      0.0
# 3  Cologne.pnml-Wuerzburg.pnml   2   14  ...   4205220774    0.737469      0.0
# 4  Cologne.pnml-Frankfurt.pnml   8    8  ...   4472867536    0.834402      0.0
#
# [5 rows x 13 columns]

# %%
uni_bert_ft.head()
# Out:
#                           Name  TP   FP  ...      BP TIME  SIMILARITY  MIP GAP
# 0           Aggregated (MACRO)  84  339  ...  35126567189    0.000000      0.0
# 1           Aggregated (MICRO)  84  339  ...  35126567189    0.000000      0.0
# 2  Cologne.pnml-FU_Berlin.pnml   3   13  ...  10472814737    0.934561      0.0
# 3  Cologne.pnml-Wuerzburg.pnml   2   14  ...   4843886859    0.937433      0.0
# 4  Cologne.pnml-Frankfurt.pnml   8    8  ...   5009364849    0.963163      0.0
#
# [5 rows x 13 columns]

# %%
uni_bow_ilp.head()

# %%
uni_bert_ilp.head()

# %%
uni_bert_ft_ilp.head()
# Out:
#                           Name  TP   FP  ...      BP TIME  SIMILARITY   MIP GAP
# 0           Aggregated (MACRO)  89  334  ...  29922719255    0.000000  0.000000
# 1           Aggregated (MICRO)  89  334  ...  29922719255    0.000000  0.000000
# 2  Cologne.pnml-FU_Berlin.pnml   4   12  ...   8299030376    0.863782  0.103464
# 3  Cologne.pnml-Wuerzburg.pnml   3   13  ...   4414209242    0.854182  0.116656
# 4  Cologne.pnml-Frankfurt.pnml   5   11  ...   4559302113    0.848708  0.147879
#
# [5 rows x 13 columns]
